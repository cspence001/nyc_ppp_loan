# %%
import pandas as pd
import numpy as np

# %%
allData = pd.read_csv("../../static/data/geo/nycppprecipients_geo.csv")

# %%
allData_df = pd.DataFrame(allData)
allData_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        LoanRange                   BusinessName  \
# 0           0             0  a $5-10 million   1186 BROADWAY RESTAURANT LLC
# 1           1             1  a $5-10 million    246 SPRING STREET (NY), LLC
# 2           2             2  a $5-10 million  ABRAHAM JOSHUA HESCHEL SCHOOL
# 3           3             3  a $5-10 million           ACCESS STAFFING, LLC
# 4           4             4  a $5-10 million  ACCUITY DELIVERY SYSTEMS, LLC
#
#                        Address      City State    Zip  NAICSCode  \
# 0         30 West 26th Street   NEW YORK    NY  10010     721110
# 1                246 SPRING ST  NEW YORK    NY  10013     721110
# 2              20 West End Ave  NEW YORK    NY  10023     611110
# 3  360 Lexington Ave 8th Floor  NEW YORK    NY  10017     561311
# 4       810 7TH AVE Suite 1110  NEW YORK    NY  10019     541511
#
#                                             Industry  \
# 0                     Accomodation and Food Services
# ...

# %%
import csv 
import json
import time

def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 
        
        num_rows = 0
        #convert each csv row into python dict
        for row in csvReader: 
            num_rows +=1
            #add this python dict to json array
            jsonArray.append(row)
            
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = r'../../static/data/geo/nycppprecipients_geo.csv'
jsonFilePath = r'../../static/data/geo/nycppprecipients_geo.json'

start = time.perf_counter()
csv_to_json(csvFilePath, jsonFilePath)
finish = time.perf_counter()

print(f"Conversion completed successfully in {finish - start:0.4f} seconds")
# Out:
# Conversion completed successfully in 0.5199 seconds
